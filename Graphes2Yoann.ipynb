# %% [markdown]
# <a href="https://colab.research.google.com/github/YoannRaguenes/Projet-Data-Science-Clubs-De-Foot-Anglais/blob/master/Graphes2Yoann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pylab

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("worldplayers (6).csv")

# %%
tab=pd.read_csv("EnglishClubsStats (1).csv")

# %%
df.loc[(df['Gls'])>18]
# Out:
#        Unnamed: 0                 name   Nation  ...   G+A  G-PK G+A-PK
# 452           453          Jamie Vardy  eng ENG  ...  0.93  0.61   0.77
# 903           412  Aleksandar Mitrović   rs SRB  ...  0.71  0.62   0.65
# 1130          639        Ollie Watkins  eng ENG  ...  0.65  0.60   0.65
# 1766          597           Ivan Toney  eng ENG  ...  0.92  0.70   0.86
# 2002          173           Eoin Doyle   ie IRL  ...  1.04  0.83   0.97
# 3011          479        Scott Quigley  eng ENG  ...   NaN  0.64    NaN
# 3523          315         Lionel Messi   ar ARG  ...  1.48  0.76   1.33
# 4317          579     Cristhian Stuani   uy URU  ...  0.94  0.63   0.67
# 4622          250   Robert Lewandowski   pl POL  ...  1.23  0.97   1.10
# 4828          456          Timo Werner   de GER  ...  1.23  0.79   1.10
# 6115          254        Tino Kadewere   zw ZIM  ...  1.04  0.61   0.78
# 6634          225        Ciro Immobile   it ITA  ...  1.40  0.70   0.99
# ...

# %%
df.loc[ (df['Age']<=20) & (df['Gls']>=10)]
# Out:
#        Unnamed: 0                   name   Nation  ...   G+A  G-PK G+A-PK
# 880           389           Bryan Mbeumo   fr FRA  ...  0.75  0.52   0.75
# 1375          206           Marcus Forss   fi FIN  ...  0.80  0.53   0.60
# 4172          434           Darwin Núñez   uy URU  ...  0.76  0.47   0.53
# 4738          366           Jadon Sancho  eng ENG  ...  1.44  0.70   1.44
# 5657          341          Kylian Mbappé   fr FRA  ...  1.37  1.07   1.37
# 5706          390         Victor Osimhen   ng NGA  ...  0.67  0.43   0.59
# 8282           24    Erling Braut Håland   no NOR  ...  1.83  1.37   1.74
# 8296           38            Patson Daka   zm ZAM  ...  1.63  1.32   1.63
# 10177         105         Jonathan David   ca CAN  ...  1.07  0.64   0.94
# 13210          58            Myron Boadu   nl NED  ...  0.89  0.62   0.89
# 13433         281          Donyell Malen   nl NED  ...  0.98  0.68   0.83
# 13487         335      Vangelis Pavlidis   gr GRE  ...  0.54  0.41   0.50
# ...

# %%
R1=df.loc[(df['Gls']>18)&(df['Ast']>4)]['name']

# %%
L1=[]
for elt in R1:
  L1.append(elt)

# %%
R2=df.loc[(df['Gls']>18)&(df['Ast']>4)]['Gls']

# %%
L2=[]
for elt in R2:
  L2.append(elt)

# %%
fig = plt.figure()
barName=[]
x = L1
height = L2
width = 0.2

plt.bar(x, height, width, color='b' )
plt.title("buts marques par joueurs plus de 18 buts et 4 passes")

plt.show()

# %%
labels = L1
sizes = L2
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

plt.pie(sizes, labels=labels, colors=colors, 
        autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.title("buts marques par joueurs plus de 18 buts et 4 passes")
plt.show()

# %%
R3=df.loc[(df['Squad']=='Brest')&(df['Gls']>1)]['name']

# %%
R4=df.loc[(df['Squad']=='Brest')&(df['Gls']>1)]['Gls']

# %%
R5=df.loc[(df['Squad']=='Brest')&(df['Gls']>1)]['Min']

# %%
L3=[]
for elt in R3:
  L3.append(elt)

# %%
L4=[]
for elt in R4:
  L4.append(elt)

# %%
L5=[]
for elt in R5:
  elt=str(elt)
  if len(elt)<4:
    elt=int(elt)
    L5.append(elt)
  else:
    elt=elt.replace(',','')
    elt=int(elt)
    L5.append(elt)

# %%
labels = L3
sizes = L5
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','green','purple']

plt.pie(sizes, labels=labels, colors=colors, 
        autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.title("BUTS MARQUES PAR LES JOUEURS D'UNE EQUIPE DONNEE")
plt.show()

# %%
# Jeunes joueurs avec un bon rendement pour une equipe donnee

df.loc[(df['Squad']=='Blackpool')&(df['Age']<23)&(df['G+A-PK']>0.30)]
# Out:
#       Unnamed: 0                   name   Nation  ...   G+A  G-PK G+A-PK
# 1322         153  Kiernan Dewsbury Hall  eng ENG  ...  0.53  0.42   0.53
#
# [1 rows x 22 columns]

# %%
def win_rates(league):
  wr=[]
  games_home = tab.loc[((tab['league'])==league) & ((tab['name'])!='Bury')]["games_home"]
  wins_home = tab.loc[((tab['league'])==league) & ((tab['name'])!='Bury')]["wins_home"]
  games_away = tab.loc[((tab['league'])==league) & ((tab['name'])!='Bury')]["games_away"]
  wins_away = tab.loc[((tab['league'])==league) & ((tab['name'])!='Bury')]["wins_away"]
  name = tab.loc[((tab['league'])==league) & ((tab['name'])!='Bury')]["name"] 
  if(league== 'National League'):
    index=0
    index2=24
  if(league== 'League Two'):
    index=24
    index2=24
  if(league== 'League One'):
    index=48
    index2=23
  if(league== 'Championship'):
    index=72
    index2=24
  if(league== 'Premier League'):
    index=96
    index2=20              
  for i in range(index,index+index2):
    s=wins_home[i]+wins_away[i]
    s=s/(games_home[i]+games_away[i])*100
    wr.append(s)
    wr.sort()
    wr.reverse()
  return wr,name,index,index2

# %%
WRtest=win_rates('League One')

# %%
WRtest
# Out:
# ([52.94117647058824,
#   51.42857142857142,
#   50.0,
#   48.57142857142857,
#   48.57142857142857,
#   48.57142857142857,
#   45.714285714285715,
#   44.44444444444444,
#   44.11764705882353,
#   38.88888888888889,
#   34.285714285714285,
#   34.285714285714285,
#   34.285714285714285,
#   34.285714285714285,
#   31.428571428571427,
#   29.411764705882355,
#   29.411764705882355,
#   28.57142857142857,
#   28.57142857142857,
#   23.52941176470588,
#   22.857142857142858,
#   14.705882352941178,
#   11.428571428571429],
#  48      Coventry City
#  49      Rotherham Utd
#  50      Oxford United
#  51         Portsmouth
#  52     Fleetwood Town
#  53      P'borough Utd
#  54         Sunderland
#  55            Wycombe
#  56          Doncaster
#  57       Ipswich Town
#  58         Gillingham
#  59      Burton Albion
#  60          Blackpool
#  61     Bristol Rovers
#  62       Lincoln City
#  63         Shrewsbury
#  64    Acc'ton Stanley
#  65            MK Dons
# ...

# %%
def goals_for_home_avg(league):
  R10=tab.loc[(tab['league']==league)]['goals_for_home']
  sum=0
  for elt in R10:
    sum+=elt
  return(sum/len(R10))


def goals_against_home_avg(league):
  R11=tab.loc[(tab['league']==league)]['goals_against_home']
  sum=0
  for elt in R11:
    sum+=elt
  return(sum/len(R11))  


def goals_for_away_avg(league):
  R12=tab.loc[(tab['league']==league)]['goals_for_away']
  sum=0
  for elt in R12:
    sum+=elt
  return(sum/len(R12))   

  
def goals_against_away_avg(league):
  R13=tab.loc[(tab['league']==league)]['goals_against_away']
  sum=0
  for elt in R13:
    sum+=elt
  return(sum/len(R13))

# %%
def compare_goals(team,league):
  goals=[]
  goals.append(int(20+((tab.loc[(tab['name']==team)]['goals_for_home'])-goals_for_home_avg(league))))   
  goals.append(int(20-((tab.loc[(tab['name']==team)]['goals_against_home'])-goals_against_home_avg(league))))  
  goals.append(int(20+((tab.loc[(tab['name']==team)]['goals_for_away'])-goals_for_away_avg(league))))
  goals.append(int(20-((tab.loc[(tab['name']==team)]['goals_against_away'])-goals_against_away_avg(league))))
  return(goals)

# %%
somme=0
moy=0
for elt in compare_goals('Bolton','League Two'):
  somme+=elt
  moy=somme/4
ecarts_type=[]
for elt in compare_goals('Bolton','League Two'):
  ecarts_type.append(elt-moy)

# %%
#COMPARATIFS DES BUTS POUR UNE EQUIPE DONNEE 

import plotly.express as px
r1=[]
for elt in compare_goals('Everton','Premier League'):
  r1.append(elt)

df2 = pd.DataFrame(dict(
    r=r1,
    theta=['Buts marques a domicile','Buts encaisses a domicile','Buts marques a l exterieur',
           'Buts encaisses a l exterieur']))
fig = px.line_polar(df2, r='r', theta='theta', line_close=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="19356062-64de-4c79-aa42-ee5210be1b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("19356062-64de-4c79-aa42-ee5210be1b72")) {
#                     Plotly.newPlot(
#                         '19356062-64de-4c79-aa42-ee5210be1b72',
# ...
