# %% [markdown]
# <a href="https://colab.research.google.com/github/YoannRaguenes/Projet-Data-Science-Clubs-De-Foot-Anglais/blob/master/Graphique_Club.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tab = pd.read_csv('EnglishClubsStats (1).csv')
wins_home = tab.loc[((tab['games_home'])==15) & ((tab['league'])=='Premier League')]["wins_home"]
name = tab.loc[((tab['games_home'])==15) & ((tab['league'])=='Premier League')]["name"]

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(wins_home)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(v=val)
    return my_autopct
plt.figure(figsize=(8,8))
explodes=(0.05,0,0,0,0,0,0,0,0,0)
plt.pie(wins_home,labels = name,autopct=make_autopct(a),explode=explodes, colors =sns.color_palette("BrBG",15),textprops= {"color": "white","size":14} ,shadow=True, wedgeprops = {"linewidth":1,"edgecolor":"black"})
my_circ = plt.Circle((0,0),.75, edgecolor = "white",color = "grey")
plt.gca().add_artist(my_circ)
plt.title("NOMBRE DE MATCH GAGNES A DOMICILE POUR 15 MATCHS JOUES", color = "white", size=18)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   # Remove the CWD from sys.path while we load stuff.
